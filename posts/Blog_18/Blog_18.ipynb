# %% [raw]
# ---
# title: "What do LLMs look for in an intern?"
# description: "In this day and age promotions, jobs, and even internships don't come easy. So, with the AI revolution at our doorsteps, let's find out what LLMs, aka, future hiring managers(?) look for in an intern?"
# date: 05/01/2025
# execute:
#   output: asis
# categories:
#   - conversation
#   - learning
# ---

# %% [markdown]
# ![Intern.jpg](attachment:99319cc4-421b-414c-871b-a01c65961096.jpg)

# %% [markdown]
# To find out what LLMs look for in an intern, I'll try a direct. approach with each of Deepseek and Chat GPT 4.1, and then will give both of them an example of a stellar intern and a poorer intern, using this website as an example: https://internsdc.com/worst-best-intern-qualities/. With that, let's get into it!

# %% [markdown]
# ### **First Prompt to Deepseek**
